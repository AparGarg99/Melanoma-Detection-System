# %%
import pandas as pd
import os
import shutil

# %%
df = pd.read_csv('processed_data_ham.csv')

# %%
df
# Out:
#               Name  Family_History  Patient_History Patient_Sex  Patient_Age  \
# 0     ISIC_0009868           False            False      female         70.0
# 1     ISIC_0009869           False             True      female         40.0
# 2     ISIC_0009870           False             True      female         40.0
# 3     ISIC_0009871           False            False        male         45.0
# 4     ISIC_0009872           False            False      female         50.0
# ...            ...             ...              ...         ...          ...
# 1456  ISIC_0011398           False            False      female         50.0
# 1457  ISIC_0011399           False            False        male         85.0
# 1458  ISIC_0011400           False            False      female         50.0
# 1459  ISIC_0011402           False            False        male         20.0
# 1460  ISIC_0024262           False            False        male         55.0
#
#       Melanoma
# 0         True
# ...

# %%
c=0
root='ISIC_all'
for path, subdirs, files in os.walk(root):
    for name in files:
        file_path = os.path.join(path, name)
        x = name[:-5]
        if(x in list(df['Name'])):
            c=c+1
            shutil.copy(file_path, 'ISIC_selected')

# %%
c
# Out:
# 1460
