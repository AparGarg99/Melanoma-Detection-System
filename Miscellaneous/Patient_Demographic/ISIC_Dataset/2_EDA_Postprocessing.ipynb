# %% [markdown]
# # Read Dataset

# %%
import pandas as pd
df=pd.read_csv('processed_data_isic.csv')
df.head()
# Out:
#    Family_History  Patient_History Patient_Sex  Patient_Age  Melanoma
# 0           False            False      female         70.0      True
# 1           False             True      female         40.0     False
# 2           False            False        male         45.0     False
# 3           False            False      female         50.0     False
# 4           False             True      female         30.0     False

# %% [markdown]
# # Automated EDA

# %% [markdown]
# ## Pandas Profiling
#
# Documentation: https://pypi.org/project/pandas-profiling/

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
profile.to_file("eda_postprocessing_report.html")
# Out:
# Summarize dataset:   0%|          | 0/18 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## AutoViz
#
# Documentation: https://pypi.org/project/autoviz/

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported AutoViz_Class version: 0.0.84. Call using:
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 does not show plot but creates them and saves them in AutoViz_Plots directory in your local machine.

# %%
AV = AutoViz_Class()
sep = ","
dft = AV.AutoViz(
    filename='',
    sep=",",
    depVar="Melanoma",
    dfte=df,
    header=0,
    verbose=1,
    lowess=True,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
# Shape of your Data Set loaded: (189, 5)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  1
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     4 Predictors classified...
#         This does not include the Target column(s)
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Binary_Classification VISUALIZATION Started #####################
# Data Set Shape: 189 rows, 5 cols
# Data Set columns info:
# * Family_History: 0 nulls, 2 unique vals, most common: {False: 109, True: 80}
# * Patient_History: 0 nulls, 2 unique vals, most common: {False: 102, True: 87}
# * Patient_Sex: 0 nulls, 2 unique vals, most common: {'female': 98, 'male': 91}
# * Patient_Age: 0 nulls, 18 unique vals, most common: {65.0: 15, 75.0: 15}
# * Melanoma: 0 nulls, 2 unique vals, most common: {False: 114, True: 75}
# --------------------------------------------------------------------
#    Columns to delete:
# '   []'
#    Boolean variables %s
# "   ['Family_History', 'Patient_History', 'Patient_Sex']"
#    Categorical variables %s
# "   ['Family_History', 'Patient_History', 'Patient_Sex']"
#    Continuous variables %s
# "   ['Patient_Age']"
#    Discrete string variables %s
# '   []'
#    Date and time variables %s
# '   []'
#    ID variables %s
# '   []'
#    Target variable %s
# '   Melanoma'
# Using Lowess Smoothing. This might take a few minutes for large data sets...
# Could not draw Violin Plots
# Time to run AutoViz (in seconds) = 1.307
#
#  ###################### VISUALIZATION Completed ########################
