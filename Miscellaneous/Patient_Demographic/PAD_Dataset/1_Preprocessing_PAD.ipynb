# %%
import pandas as pd

# %%
df = pd.read_csv('PAD_dataset/metadata.csv')
df.head()
# Out:
#   patient_id  lesion_id  smoke  drink background_father background_mother  \
# 0   PAT_1516       1765    NaN    NaN               NaN               NaN
# 1     PAT_46        881  False  False         POMERANIA         POMERANIA
# 2   PAT_1545       1867    NaN    NaN               NaN               NaN
# 3   PAT_1989       4061    NaN    NaN               NaN               NaN
# 4    PAT_684       1302  False   True         POMERANIA         POMERANIA
#
#    age pesticide  gender skin_cancer_history  ... diameter_2 diagnostic  \
# 0    8       NaN     NaN                 NaN  ...        NaN        NEV
# 1   55     False  FEMALE                True  ...        5.0        BCC
# 2   77       NaN     NaN                 NaN  ...        NaN        ACK
# 3   75       NaN     NaN                 NaN  ...        NaN        ACK
# 4   79     False    MALE                True  ...        5.0        BCC
#
#     itch   grew   hurt  changed  bleed elevation                 img_id  \
# ...

# %%
df.shape
# Out:
# (2298, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2298 entries, 0 to 2297
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   patient_id           2298 non-null   object
#  1   lesion_id            2298 non-null   int64
#  2   smoke                1494 non-null   object
#  3   drink                1494 non-null   object
#  4   background_father    1480 non-null   object
#  5   background_mother    1476 non-null   object
#  6   age                  2298 non-null   int64
#  7   pesticide            1494 non-null   object
#  8   gender               1494 non-null   object
#  9   skin_cancer_history  1494 non-null   object
#  10  cancer_history       1494 non-null   object
#  11  has_piped_water      1494 non-null   object
#  12  has_sewage_system    1494 non-null   object
#  13  fitspatrick          1494 non-null   float64
#  14  region               2298 non-null   object
# ...

# %%
l=['smoke', 'drink', 'background_father',
       'background_mother', 'age', 'pesticide', 'gender',
       'skin_cancer_history', 'cancer_history','has_piped_water','has_sewage_system','diagnostic']

# %%
df=df[l]

# %%
df
# Out:
#       smoke  drink background_father background_mother  age pesticide  gender  \
# 0       NaN    NaN               NaN               NaN    8       NaN     NaN
# 1     False  False         POMERANIA         POMERANIA   55     False  FEMALE
# 2       NaN    NaN               NaN               NaN   77       NaN     NaN
# 3       NaN    NaN               NaN               NaN   75       NaN     NaN
# 4     False   True         POMERANIA         POMERANIA   79     False    MALE
# ...     ...    ...               ...               ...  ...       ...     ...
# 2293    NaN    NaN               NaN               NaN   73       NaN     NaN
# 2294  False  False         POMERANIA         POMERANIA   55     False  FEMALE
# 2295    NaN    NaN               NaN               NaN   74       NaN     NaN
# 2296  False  False         POMERANIA         POMERANIA   58      True  FEMALE
# 2297    NaN    NaN               NaN               NaN   41       NaN     NaN
#
# ...

# %%
df = df.dropna(how='any')

# %%
df['Melanoma']=df['diagnostic'].apply(lambda x:'False' if x!='MEL' else 'True')
# Out:
# <ipython-input-9-6982c4d516e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Melanoma']=df['diagnostic'].apply(lambda x:'False' if x!='MEL' else 'True')

# %%
df=df.drop('diagnostic',axis=1)

# %%
df = df.drop_duplicates()

# %%
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (848, 12)

# %%
df.head()
# Out:
#    smoke  drink background_father background_mother  age pesticide  gender  \
# 0  False  False         POMERANIA         POMERANIA   55     False  FEMALE
# 1  False   True         POMERANIA         POMERANIA   79     False    MALE
# 2  False   True           GERMANY             ITALY   52     False  FEMALE
# 3  False  False         POMERANIA         POMERANIA   74      True  FEMALE
# 4  False   True           GERMANY           GERMANY   58      True  FEMALE
#
#   skin_cancer_history cancer_history has_piped_water has_sewage_system  \
# 0                True           True            True              True
# 1                True          False           False             False
# 2               False           True            True              True
# 3               False          False           False             False
# 4                True           True            True              True
#
#   Melanoma
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
df.to_csv('processed_data_pad.csv',index=False)

# %%
df['Melanoma'].value_counts()
# Out:
# False    812
# True      36
# Name: Melanoma, dtype: int64
