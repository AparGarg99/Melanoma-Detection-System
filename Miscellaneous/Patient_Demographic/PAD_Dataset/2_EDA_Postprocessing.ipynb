# %% [markdown]
# # Read Dataset

# %%
import pandas as pd
df=pd.read_csv('processed_data_pad.csv')
df.head()
# Out:
#    smoke  drink background_father background_mother  age  pesticide  gender  \
# 0  False  False         POMERANIA         POMERANIA   55      False  FEMALE
# 1  False   True         POMERANIA         POMERANIA   79      False    MALE
# 2  False   True           GERMANY             ITALY   52      False  FEMALE
# 3  False  False         POMERANIA         POMERANIA   74       True  FEMALE
# 4  False   True           GERMANY           GERMANY   58       True  FEMALE
#
#    skin_cancer_history  cancer_history  has_piped_water  has_sewage_system  \
# 0                 True            True             True               True
# 1                 True           False            False              False
# 2                False            True             True               True
# 3                False           False            False              False
# 4                 True            True             True               True
#
#    Melanoma
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %% [markdown]
# # Automated EDA

# %% [markdown]
# ## Pandas Profiling
#
# Documentation: https://pypi.org/project/pandas-profiling/

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
profile.to_file("eda_postprocessing_report.html")
# Out:
# Summarize dataset:   0%|          | 0/25 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## AutoViz
#
# Documentation: https://pypi.org/project/autoviz/

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported AutoViz_Class version: 0.0.84. Call using:
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 does not show plot but creates them and saves them in AutoViz_Plots directory in your local machine.

# %%
AV = AutoViz_Class()
sep = ","
dft = AV.AutoViz(
    filename='',
    sep=",",
    depVar="Melanoma",
    dfte=df,
    header=0,
    verbose=1,
    lowess=True,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
# Shape of your Data Set loaded: (848, 12)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  8
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     11 Predictors classified...
#         This does not include the Target column(s)
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Binary_Classification VISUALIZATION Started #####################
# Data Set Shape: 848 rows, 12 cols
# Data Set columns info:
# * smoke: 0 nulls, 2 unique vals, most common: {False: 743, True: 105}
# * drink: 0 nulls, 2 unique vals, most common: {False: 616, True: 232}
# * background_father: 0 nulls, 13 unique vals, most common: {'POMERANIA': 292, 'GERMANY': 274}
# * background_mother: 0 nulls, 11 unique vals, most common: {'POMERANIA': 298, 'GERMANY': 279}
# * age: 0 nulls, 74 unique vals, most common: {58: 31, 71: 29}
# * pesticide: 0 nulls, 2 unique vals, most common: {False: 494, True: 354}
# * gender: 0 nulls, 2 unique vals, most common: {'FEMALE': 437, 'MALE': 411}
# * skin_cancer_history: 0 nulls, 2 unique vals, most common: {False: 465, True: 383}
# * cancer_history: 0 nulls, 2 unique vals, most common: {True: 448, False: 400}
# * has_piped_water: 0 nulls, 2 unique vals, most common: {True: 526, False: 322}
# * has_sewage_system: 0 nulls, 2 unique vals, most common: {True: 479, False: 369}
# * Melanoma: 0 nulls, 2 unique vals, most common: {False: 812, True: 36}
# --------------------------------------------------------------------
#    Columns to delete:
# '   []'
#    Boolean variables %s
# ("   ['smoke', 'drink', 'pesticide', 'gender', 'skin_cancer_history', "
#  "'cancer_history', 'has_piped_water', 'has_sewage_system']")
#    Categorical variables %s
# ("   ['background_father', 'background_mother', 'smoke', 'drink', 'pesticide', "
#  "'gender', 'skin_cancer_history', 'cancer_history', 'has_piped_water', "
#  "'has_sewage_system']")
#    Continuous variables %s
# "   ['age']"
#    Discrete string variables %s
# '   []'
#    Date and time variables %s
# '   []'
#    ID variables %s
# '   []'
#    Target variable %s
# '   Melanoma'
# Using Lowess Smoothing. This might take a few minutes for large data sets...
# Could not draw Violin Plots
# Could not draw Pivot Charts against Dependent Variable
# Time to run AutoViz (in seconds) = 3.169
#
#  ###################### VISUALIZATION Completed ########################
